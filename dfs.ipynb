# %%
import pandas as pd

# %%
# Reading in the data sets downloaded from https://data.louisvilleky.gov
expenditures_2019 = pd.read_csv('Lou_Data/eExpenditures_2019.csv', low_memory=False)
expenditures_2020 = pd.read_csv('Lou_Data/eExpenditures_2020.csv', low_memory=False)
expenditures_2021 = pd.read_csv('Lou_Data/eExpenditures_2021.csv', low_memory=False)
expenditures_2022 = pd.read_csv('Lou_Data/eExpenditures_2022.csv', low_memory=False)

stops_2019 = pd.read_csv('Lou_Data/LMPD_STOP_DATA_2019.csv', low_memory=False)
stops_2020 = pd.read_csv('Lou_Data/LMPD_STOP_DATA_2020.csv', low_memory=False)
stops_2021 = pd.read_csv('Lou_Data/LMPD_STOP_DATA_2021.csv', low_memory=False)
stops_2022 = pd.read_csv('Lou_Data/LMPD_STOP_DATA_2022.csv', low_memory=False)

crime_data_2018 = pd.read_csv('Lou_Data/Louisville_Metro_KY_-_Crime_Data_2018.csv', low_memory=False)
crime_data_2019 = pd.read_csv('Lou_Data/Louisville_Metro_KY_-_Crime_Data_2019.csv', low_memory=False)
crime_data_2020 = pd.read_csv('Lou_Data/Louisville_Metro_KY_-_Crime_Data_2020.csv', low_memory=False)
crime_data_2021 = pd.read_csv('Lou_Data/Louisville_Metro_KY_-_Crime_Data_2021.csv', low_memory=False)
crime_data_2022 = pd.read_csv('Lou_Data/Louisville_Metro_KY_-_Crime_Data_2022.csv', low_memory=False)

employee_characteristics = pd.read_csv('Lou_Data/Louisville_Metro_KY_-_LMPD_Employee_Characteristics.csv', low_memory=False)

# %%
expenditures_All = pd.concat([expenditures_2019, expenditures_2020, expenditures_2021, expenditures_2022])
stops_All = pd.concat([stops_2019, stops_2020, stops_2021, stops_2022])
crime_data_All = pd.concat([crime_data_2018, crime_data_2019, crime_data_2020, crime_data_2021, crime_data_2022])

# %%
expenditures_All
# Out:
#         Fiscal_Year                  Budget_Type  \
# 0              2019     Metro Government Capital
# 1              2019     Metro Government Capital
# 2              2019     Metro Government Capital
# 3              2019     Metro Government Capital
# 4              2019     Metro Government Capital
# ...             ...                          ...
# 163626         2022  Metro Government Operations
# 163627         2022  Metro Government Operations
# 163628         2022  Metro Government Operations
# 163629         2022  Metro Government Operations
# 163630         2022  Metro Government Operations
#
#                              Agency_Name                  Sub_Agency_Name  \
# 0       Public Works & Assets Department      18th & Broadway Realignment
# 1       Public Works & Assets Department      18th & Broadway Realignment
# 2       Public Works & Assets Department      18th & Broadway Realignment
# 3       Public Works & Assets Department      18th & Broadway Realignment
# 4       Public Works & Assets Department      18th & Broadway Realignment
# ...                                  ...                              ...
# 163626   Facilities and Fleet Management  Facilities and Fleet Management
# 163627   Facilities and Fleet Management  Facilities and Fleet Management
# 163628   Facilities and Fleet Management  Facilities and Fleet Management
# 163629   Facilities and Fleet Management  Facilities and Fleet Management
# 163630   Facilities and Fleet Management  Facilities and Fleet Management
#
#                DepartmentName     Sub_DepartmentName              Category  \
# 0                         NaN                    NaN  Contractual Services
# 1                         NaN                    NaN  Contractual Services
# 2                         NaN                    NaN  Contractual Services
# 3                         NaN                    NaN  Contractual Services
# 4                         NaN                    NaN  Contractual Services
# ...                       ...                    ...                   ...
# 163626  Facilities Management  Facilities Management  Contractual Services
# 163627  Facilities Management  Facilities Management  Contractual Services
# 163628  Facilities Management  Facilities Management  Contractual Services
# 163629  Facilities Management  Facilities Management  Contractual Services
# 163630  Facilities Management  Facilities Management  Contractual Services
#
#                             Sub_Category  Stimulus_Type Funding_Source  \
# 0                Payments to Contractors            NaN      CDBG 2013
# 1                Payments to Contractors            NaN      CDBG 2013
# 2                Payments to Contractors            NaN      CDBG 2013
# 3                Payments to Contractors            NaN      CDBG 2013
# 4                Payments to Contractors            NaN      CDBG 2013
# ...                                  ...            ...            ...
# 163626  Fire Suppression System Services            NaN   General Fund
# 163627  Fire Suppression System Services            NaN   General Fund
# 163628  Fire Suppression System Services            NaN   General Fund
# 163629  Fire Suppression System Services            NaN   General Fund
# 163630  Fire Suppression System Services            NaN   General Fund
#
#                                 Vendor_Name  InvoiceID   InvoiceDt  \
# 0           STANTEC CONSULTING SERVICES INC  1967040.0   9/21/2018
# 1           STANTEC CONSULTING SERVICES INC  1975819.0  10/26/2018
# 2           STANTEC CONSULTING SERVICES INC  1975819.0  10/26/2018
# 3           STANTEC CONSULTING SERVICES INC  1975819.0  10/26/2018
# 4           STANTEC CONSULTING SERVICES INC  1975819.0  10/26/2018
# ...                                     ...        ...         ...
# 163626  JOHNSON CONTROLS FIRE PROTECTION LP  2407247.0  2021-09-16
# 163627  JOHNSON CONTROLS FIRE PROTECTION LP  2407247.0  2021-09-16
# 163628  JOHNSON CONTROLS FIRE PROTECTION LP  2407247.0  2021-09-16
# 163629  JOHNSON CONTROLS FIRE PROTECTION LP  2407247.0  2021-09-16
# 163630  JOHNSON CONTROLS FIRE PROTECTION LP  2407247.0  2021-09-16
#
#         InvoiceAmt  DistributionAmt    CheckID     CheckDt  CheckAmt  \
# 0         15537.03         15537.03  1005494.0  10/16/2018  15537.03
# 1         19103.52          4396.94  1008192.0   11/1/2018  19103.52
# 2         19103.52         -4396.94  1008192.0   11/1/2018  19103.52
# 3         19103.52         15282.82  1008192.0   11/1/2018  19103.52
# 4         19103.52        -15282.82  1008192.0   11/1/2018  19103.52
# ...            ...              ...        ...         ...       ...
# 163626    27898.88          1978.73  1192813.0  2022-02-07  27898.88
# 163627    27898.88           529.78  1192813.0  2022-02-07  27898.88
# 163628    27898.88           412.54  1192813.0  2022-02-07  27898.88
# 163629    27898.88          1641.60  1192813.0  2022-02-07  27898.88
# 163630    27898.88          1862.17  1192813.0  2022-02-07  27898.88
#
#        CheckVoidDt
# 0         1/1/1900
# 1         1/1/1900
# 2         1/1/1900
# 3         1/1/1900
# 4         1/1/1900
# ...            ...
# 163626  1900-01-01
# 163627  1900-01-01
# 163628  1900-01-01
# 163629  1900-01-01
# 163630  1900-01-01
#
# [529009 rows x 19 columns]

# %%
stops_All
# Out:
#                        TYPE_OF_STOP CITATION_CONTROL_NUMBER ACTIVITY RESULTS  \
# 0      COMPLAINT/CRIMINAL VIOLATION            CX00823       CITATION ISSUED
# 1      COMPLAINT/CRIMINAL VIOLATION            CX03321       CITATION ISSUED
# 2      COMPLAINT/CRIMINAL VIOLATION            DA80633       CITATION ISSUED
# 3      COMPLAINT/CRIMINAL VIOLATION            DA80694       CITATION ISSUED
# 4      COMPLAINT/CRIMINAL VIOLATION            DA90410       CITATION ISSUED
# ...                             ...                     ...              ...
# 28075             TRAFFIC VIOLATION            EF73378       CITATION ISSUED
# 28076             TRAFFIC VIOLATION            EF73418       CITATION ISSUED
# 28077             TRAFFIC VIOLATION            EF73562       CITATION ISSUED
# 28078             TRAFFIC VIOLATION            EF73570       CITATION ISSUED
# 28079             TRAFFIC VIOLATION            EF73574       CITATION ISSUED
#
#       OFFICER_GENDER OFFICER_RACE OFFICER_AGE_RANGE ACTIVITY_DATE  \
# 0                  M        WHITE           31 - 40    09/29/2019
# 1                  M        WHITE           41 - 50    02/17/2019
# 2                  F        BLACK           31 - 40    12/01/2019
# 3                  M        WHITE           31 - 40    02/19/2019
# 4                  M        WHITE           41 - 50    02/08/2019
# ...              ...          ...               ...           ...
# 28075              M        WHITE           31 - 40    12/31/2022
# 28076              M        WHITE           31 - 40    12/31/2022
# 28077              M        BLACK           31 - 40    12/31/2022
# 28078              M        BLACK           31 - 40    12/31/2022
# 28079              M        BLACK           21 - 30    12/31/2022
#
#       ACTIVITY_TIME                                  ACTIVITY_LOCATION  \
# 0             23:48                4700 BLOCK  BARDSTOWN RD @ CIRCLE K
# 1             03:26  SHELBYVILLE RD                                ...
# 2             00:34  N 30TH ST                                     ...
# 3             19:50  GARDINER LN                                   ...
# 4             13:45  SOUTHERN PKWY                                 ...
# ...             ...                                                ...
# 28075         19:42  I-264WB @ MM 9                                ...
# 28076         22:54  BARDSTOWN RD/RANDOM WAY                       ...
# 28077         22:26  BARDSTOWN RD                                  ...
# 28078         22:56  BARDSTOWN RD                                  ...
# 28079         23:18  BAXTER AVE/CASTLEWOOD AVE                     ...
#
#       ACTIVITY_DIVISION ACTIVITY_BEAT DRIVER_GENDER DRIVER_RACE  \
# 0          5TH DIVISION        BEAT 2             M       WHITE
# 1          8TH DIVISION        BEAT 4             M       BLACK
# 2          1ST DIVISION        BEAT 1             M       WHITE
# 3          5TH DIVISION        BEAT 4             F       WHITE
# 4          3RD DIVISION        BEAT 2             M       BLACK
# ...                 ...           ...           ...         ...
# 28075      4TH DIVISION        BEAT 3             M       BLACK
# 28076      6TH DIVISION        BEAT 4             M    HISPANIC
# 28077      5TH DIVISION        BEAT 2             M       BLACK
# 28078      5TH DIVISION        BEAT 2             M       BLACK
# 28079      5TH DIVISION        BEAT 2             M       BLACK
#
#       DRIVER_AGE_RANGE  NUMBER OF PASSENGERS WAS_VEHCILE_SEARCHED  \
# 0              31 - 40                     0                   NO
# 1              20 - 25                     0                  YES
# 2              20 - 25                     0                  YES
# 3              OVER 60                     0                   NO
# 4              20 - 25                     0                  YES
# ...                ...                   ...                  ...
# 28075          20 - 25                     1                   NO
# 28076          31 - 40                     2                   NO
# 28077          26 - 30                     0                   NO
# 28078          20 - 25                     0                   NO
# 28079          26 - 30                     0                   NO
#
#        REASON_FOR_SEARCH
# 0                    NaN
# 1                    3.0
# 2                    2.0
# 3                    NaN
# 4                    3.0
# ...                  ...
# 28075                NaN
# 28076                NaN
# 28077                NaN
# 28078                NaN
# 28079                NaN
#
# [105021 rows x 17 columns]

# %%
crime_data_All.dtypes
# Out:
# INCIDENT_NUMBER     object
# DATE_REPORTED       object
# DATE_OCCURED        object
# UOR_DESC            object
# CRIME_TYPE          object
# NIBRS_CODE          object
# UCR_HIERARCHY       object
# ATT_COMP            object
# LMPD_DIVISION       object
# LMPD_BEAT           object
# PREMISE_TYPE        object
# BLOCK_ADDRESS       object
# CITY                object
# ZIP_CODE            object
# ID                 float64
# ObjectId             int64
# City                object
# BADGE_ID            object
# dtype: object

# %%
crime_data_All
# Out:
#       INCIDENT_NUMBER        DATE_REPORTED         DATE_OCCURED  \
# 0        80-18-023451     3/30/18 11:44 AM     3/28/18 11:00 PM
# 1        80-18-026875      4/13/18 5:36 AM      3/12/18 2:00 PM
# 2        80-18-084991     10/30/18 7:08 AM     10/27/18 1:13 AM
# 3        80-18-023451     3/30/18 11:44 AM     3/28/18 11:00 PM
# 4        80-18-025979       4/9/18 3:10 PM       4/9/18 3:10 PM
# ...               ...                  ...                  ...
# 71035    80-23-500106  2022/12/20 08:26:00  2022/12/16 14:30:00
# 71036    80-23-500107  2022/12/20 08:59:00  2022/12/17 15:00:00
# 71037    80-23-500108  2022/12/20 09:54:00  2022/12/10 09:40:00
# 71038    80-23-500109  2022/12/20 10:13:00  2022/12/12 15:50:00
# 71039    80-23-500110  2022/12/20 11:05:00  2022/12/19 19:00:00
#
#                                            UOR_DESC                CRIME_TYPE  \
# 0                             BURGLARY - 3RD DEGREE                  BURGLARY
# 1                 TBUT OR DISP FROM BUILDING < $500             THEFT/LARCENY
# 2      OBSCURING THE IDENTITY OF A MACHINE U/$10000                     FRAUD
# 3                             BURGLARY - 3RD DEGREE                  BURGLARY
# 4                                 POSS OF MARIJUANA  DRUGS/ALCOHOL VIOLATIONS
# ...                                             ...                       ...
# 71035      TBUT OR DISP ALL OTHERS $1,000 < $10,000             THEFT/LARCENY
# 71036                          THEFT OF MAIL MATTER             THEFT/LARCENY
# 71037       PROPERTY LOST OR ABANDONED NON CRIMINAL                     OTHER
# 71038                      HARASSING COMMUNICATIONS                     OTHER
# 71039      TBUT PARTS FROM VEHICLE $1,000 < $10,000    VEHICLE BREAK-IN/THEFT
#
#       NIBRS_CODE UCR_HIERARCHY   ATT_COMP LMPD_DIVISION LMPD_BEAT  \
# 0            220        PART I  COMPLETED  3RD DIVISION       315
# 1            23D        PART I  COMPLETED  5TH DIVISION       513
# 2            26A       PART II  COMPLETED  8TH DIVISION       824
# 3            220        PART I  COMPLETED  3RD DIVISION       315
# 4            35A       PART II  COMPLETED  2ND DIVISION       212
# ...          ...           ...        ...           ...       ...
# 71035        23H        PART I  COMPLETED  3RD DIVISION       334
# 71036        23H        PART I  COMPLETED  2ND DIVISION       236
# 71037        90Z       PART II  COMPLETED  3RD DIVISION       315
# 71038        90Z       PART II  COMPLETED  4TH DIVISION       411
# 71039        23G        PART I  COMPLETED  6TH DIVISION       625
#
#                                         PREMISE_TYPE  \
# 0                 NON-ATTACHED RESD GARAGE/SHED/BULD
# 1                     SPECIALTY STORE (TV, FUR, ETC)
# 2                             HIGHWAY / ROAD / ALLEY
# 3                 NON-ATTACHED RESD GARAGE/SHED/BULD
# 4                             HIGHWAY / ROAD / ALLEY
# ...                                              ...
# 71035  CONSTRUCTION SITE
# 71036  RESIDENCE / HOME
# 71037  RESIDENCE / HOME
# 71038  OTHER RESIDENCE (APARTMENT/CONDO)
# 71039  PARKING LOT / GARAGE
#
#                                            BLOCK_ADDRESS        CITY ZIP_CODE  \
# 0      8700 BLOCK TERRY RD                           ...  LOUISVILLE  40258.0
# 1      2200 BLOCK BARDSTOWN RD                       ...  LOUISVILLE  40205.0
# 2      11900 BLOCK SHELBYVILLE RD                    ...  LOUISVILLE  40243.0
# 3      8700 BLOCK TERRY RD                           ...  LOUISVILLE  40258.0
# 4      S 36TH ST / VIRGINIA AVE                      ...  LOUISVILLE  40211.0
# ...                                                  ...         ...      ...
# 71035  3100 BLOCK POND STATION RD                    ...         NaN    40272
# 71036  2600 BLOCK BENOCH AVE                         ...         NaN    40216
# 71037  9900 BLOCK EVENING STAR DR                    ...         NaN    40272
# 71038  1400 BLOCK S 4TH ST                           ...         NaN    40208
# 71039  2800 BLOCK HIKES LN                           ...         NaN    40218
#
#              ID  ObjectId        City          BADGE_ID
# 0      134262.0         1         NaN               NaN
# 1      159181.0         2         NaN               NaN
# 2       64930.0         3         NaN               NaN
# 3      134263.0         4         NaN               NaN
# 4      159182.0         5         NaN               NaN
# ...         ...       ...         ...               ...
# 71035       NaN     71036  LOUISVILLE  8375
# 71036       NaN     71037  LOUISVILLE  8375
# 71037       NaN     71038  LOUISVILLE  8375
# 71038       NaN     71039  LOUISVILLE  8375
# 71039       NaN     71040  LOUISVILLE  8375
#
# [366814 rows x 18 columns]

# %%
crime_data_All['DATE_REPORTED'] = pd.to_datetime(crime_data_All['DATE_REPORTED'], infer_datetime_format=True).dt.date
crime_data_All['DATE_OCCURED'] = pd.to_datetime(crime_data_All['DATE_OCCURED'], infer_datetime_format=True).dt.date
crime_data_All['ZIP_CODE'] = crime_data_All['ZIP_CODE'].astype(str).str[:5]

crime_data_All
# Out:
#       INCIDENT_NUMBER DATE_REPORTED DATE_OCCURED  \
# 0        80-18-023451    2018-03-30   2018-03-28
# 1        80-18-026875    2018-04-13   2018-03-12
# 2        80-18-084991    2018-10-30   2018-10-27
# 3        80-18-023451    2018-03-30   2018-03-28
# 4        80-18-025979    2018-04-09   2018-04-09
# ...               ...           ...          ...
# 71035    80-23-500106    2022-12-20   2022-12-16
# 71036    80-23-500107    2022-12-20   2022-12-17
# 71037    80-23-500108    2022-12-20   2022-12-10
# 71038    80-23-500109    2022-12-20   2022-12-12
# 71039    80-23-500110    2022-12-20   2022-12-19
#
#                                            UOR_DESC                CRIME_TYPE  \
# 0                             BURGLARY - 3RD DEGREE                  BURGLARY
# 1                 TBUT OR DISP FROM BUILDING < $500             THEFT/LARCENY
# 2      OBSCURING THE IDENTITY OF A MACHINE U/$10000                     FRAUD
# 3                             BURGLARY - 3RD DEGREE                  BURGLARY
# 4                                 POSS OF MARIJUANA  DRUGS/ALCOHOL VIOLATIONS
# ...                                             ...                       ...
# 71035      TBUT OR DISP ALL OTHERS $1,000 < $10,000             THEFT/LARCENY
# 71036                          THEFT OF MAIL MATTER             THEFT/LARCENY
# 71037       PROPERTY LOST OR ABANDONED NON CRIMINAL                     OTHER
# 71038                      HARASSING COMMUNICATIONS                     OTHER
# 71039      TBUT PARTS FROM VEHICLE $1,000 < $10,000    VEHICLE BREAK-IN/THEFT
#
#       NIBRS_CODE UCR_HIERARCHY   ATT_COMP LMPD_DIVISION LMPD_BEAT  \
# 0            220        PART I  COMPLETED  3RD DIVISION       315
# 1            23D        PART I  COMPLETED  5TH DIVISION       513
# 2            26A       PART II  COMPLETED  8TH DIVISION       824
# 3            220        PART I  COMPLETED  3RD DIVISION       315
# 4            35A       PART II  COMPLETED  2ND DIVISION       212
# ...          ...           ...        ...           ...       ...
# 71035        23H        PART I  COMPLETED  3RD DIVISION       334
# 71036        23H        PART I  COMPLETED  2ND DIVISION       236
# 71037        90Z       PART II  COMPLETED  3RD DIVISION       315
# 71038        90Z       PART II  COMPLETED  4TH DIVISION       411
# 71039        23G        PART I  COMPLETED  6TH DIVISION       625
#
#                                         PREMISE_TYPE  \
# 0                 NON-ATTACHED RESD GARAGE/SHED/BULD
# 1                     SPECIALTY STORE (TV, FUR, ETC)
# 2                             HIGHWAY / ROAD / ALLEY
# 3                 NON-ATTACHED RESD GARAGE/SHED/BULD
# 4                             HIGHWAY / ROAD / ALLEY
# ...                                              ...
# 71035  CONSTRUCTION SITE
# 71036  RESIDENCE / HOME
# 71037  RESIDENCE / HOME
# 71038  OTHER RESIDENCE (APARTMENT/CONDO)
# 71039  PARKING LOT / GARAGE
#
#                                            BLOCK_ADDRESS        CITY ZIP_CODE  \
# 0      8700 BLOCK TERRY RD                           ...  LOUISVILLE    40258
# 1      2200 BLOCK BARDSTOWN RD                       ...  LOUISVILLE    40205
# 2      11900 BLOCK SHELBYVILLE RD                    ...  LOUISVILLE    40243
# 3      8700 BLOCK TERRY RD                           ...  LOUISVILLE    40258
# 4      S 36TH ST / VIRGINIA AVE                      ...  LOUISVILLE    40211
# ...                                                  ...         ...      ...
# 71035  3100 BLOCK POND STATION RD                    ...         NaN    40272
# 71036  2600 BLOCK BENOCH AVE                         ...         NaN    40216
# 71037  9900 BLOCK EVENING STAR DR                    ...         NaN    40272
# 71038  1400 BLOCK S 4TH ST                           ...         NaN    40208
# 71039  2800 BLOCK HIKES LN                           ...         NaN    40218
#
#              ID  ObjectId        City          BADGE_ID
# 0      134262.0         1         NaN               NaN
# 1      159181.0         2         NaN               NaN
# 2       64930.0         3         NaN               NaN
# 3      134263.0         4         NaN               NaN
# 4      159182.0         5         NaN               NaN
# ...         ...       ...         ...               ...
# 71035       NaN     71036  LOUISVILLE  8375
# 71036       NaN     71037  LOUISVILLE  8375
# 71037       NaN     71038  LOUISVILLE  8375
# 71038       NaN     71039  LOUISVILLE  8375
# 71039       NaN     71040  LOUISVILLE  8375
#
# [366814 rows x 18 columns]

# %%
crime_data = crime_data_All.drop(columns={'LMPD_BEAT', 'ID', 'ObjectId', 'City', 'BADGE_ID', 'ATT_COMP', 'NIBRS_CODE', 'UCR_HIERARCHY'})
crime_data
# Out:
#       INCIDENT_NUMBER DATE_REPORTED DATE_OCCURED  \
# 0        80-18-023451    2018-03-30   2018-03-28
# 1        80-18-026875    2018-04-13   2018-03-12
# 2        80-18-084991    2018-10-30   2018-10-27
# 3        80-18-023451    2018-03-30   2018-03-28
# 4        80-18-025979    2018-04-09   2018-04-09
# ...               ...           ...          ...
# 71035    80-23-500106    2022-12-20   2022-12-16
# 71036    80-23-500107    2022-12-20   2022-12-17
# 71037    80-23-500108    2022-12-20   2022-12-10
# 71038    80-23-500109    2022-12-20   2022-12-12
# 71039    80-23-500110    2022-12-20   2022-12-19
#
#                                            UOR_DESC                CRIME_TYPE  \
# 0                             BURGLARY - 3RD DEGREE                  BURGLARY
# 1                 TBUT OR DISP FROM BUILDING < $500             THEFT/LARCENY
# 2      OBSCURING THE IDENTITY OF A MACHINE U/$10000                     FRAUD
# 3                             BURGLARY - 3RD DEGREE                  BURGLARY
# 4                                 POSS OF MARIJUANA  DRUGS/ALCOHOL VIOLATIONS
# ...                                             ...                       ...
# 71035      TBUT OR DISP ALL OTHERS $1,000 < $10,000             THEFT/LARCENY
# 71036                          THEFT OF MAIL MATTER             THEFT/LARCENY
# 71037       PROPERTY LOST OR ABANDONED NON CRIMINAL                     OTHER
# 71038                      HARASSING COMMUNICATIONS                     OTHER
# 71039      TBUT PARTS FROM VEHICLE $1,000 < $10,000    VEHICLE BREAK-IN/THEFT
#
#       LMPD_DIVISION                                   PREMISE_TYPE  \
# 0      3RD DIVISION             NON-ATTACHED RESD GARAGE/SHED/BULD
# 1      5TH DIVISION                 SPECIALTY STORE (TV, FUR, ETC)
# 2      8TH DIVISION                         HIGHWAY / ROAD / ALLEY
# 3      3RD DIVISION             NON-ATTACHED RESD GARAGE/SHED/BULD
# 4      2ND DIVISION                         HIGHWAY / ROAD / ALLEY
# ...             ...                                            ...
# 71035  3RD DIVISION  CONSTRUCTION SITE
# 71036  2ND DIVISION  RESIDENCE / HOME
# 71037  3RD DIVISION  RESIDENCE / HOME
# 71038  4TH DIVISION  OTHER RESIDENCE (APARTMENT/CONDO)
# 71039  6TH DIVISION  PARKING LOT / GARAGE
#
#                                            BLOCK_ADDRESS        CITY ZIP_CODE
# 0      8700 BLOCK TERRY RD                           ...  LOUISVILLE    40258
# 1      2200 BLOCK BARDSTOWN RD                       ...  LOUISVILLE    40205
# 2      11900 BLOCK SHELBYVILLE RD                    ...  LOUISVILLE    40243
# 3      8700 BLOCK TERRY RD                           ...  LOUISVILLE    40258
# 4      S 36TH ST / VIRGINIA AVE                      ...  LOUISVILLE    40211
# ...                                                  ...         ...      ...
# 71035  3100 BLOCK POND STATION RD                    ...         NaN    40272
# 71036  2600 BLOCK BENOCH AVE                         ...         NaN    40216
# 71037  9900 BLOCK EVENING STAR DR                    ...         NaN    40272
# 71038  1400 BLOCK S 4TH ST                           ...         NaN    40208
# 71039  2800 BLOCK HIKES LN                           ...         NaN    40218
#
# [366814 rows x 10 columns]
